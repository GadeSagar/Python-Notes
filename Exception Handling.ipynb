# %% [markdown]
# ## Exception Handling in Python
# **🔹 1. What is an Exception?**
#
# - An exception is an error that happens while your program is running

# %%
a = 21 
b = 0
print(a/b)
print("Hi all")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 a = 21
#       2 b = 0
# ----> 3 print(a/b)
#       4 print("Hi all")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **🔹 2. Why Exception Handling is Needed?**
#
# - Without exception handling → program crashes.
#
# - With exception handling → program continues safely, and you can show a friendly message.

# %% [markdown]
# ## Structure

# %% [raw]
# try:
#     # code that might raise an exception
#     result = 10 / int(input("Enter divisor: "))
# except ZeroDivisionError:
#     # handles division by zero
#     print("Cannot divide by zero.")
# except ValueError:
#     # handles invalid literal for int()
#     print("Please enter a valid integer.")
# else:
#     # runs if no exception occurred
#     print("Result =", result)
# finally:
#     # always runs (cleanup)
#     print("Done.")

# %% [markdown]
# - try block: run potentially risky code.
# - If exception occurs, Python looks for a matching except.
# - If matched, the except block executes; remaining try code is skipped.
# - If no exception: else executes (optional).
# - finally executes always — good for cleanup (closing files, releasing resources).

# %% [markdown]
# ## Handling Specific Exceptions
# - Different errors → different messages.

# %%
n1 = 12
n2 = 0
print(n1/n2)
print("HI all")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 n1 = 12
#       2 n2 = 0
# ----> 3 print(n1/n2)
#       4 print("HI all")
#
# ZeroDivisionError: division by zero

# %%
try:
    n1 = 21
    n2 = 0
    print(n1 / n2)
except :
    print("division by zero")
finally:
    print("Done")
# Out:
# division by zero
# Done

# %%
try:
    num = int(input("Enter your number :-"))
    print(12/num)
except ZeroDivisionError:
    print("Division by zero")
finally:
    print("All is well")
# Out:
# Enter your number :- 0
# Division by zero
# All is well

# %% [markdown]
# - else Block (Runs only when no error)

# %%
try:
    num = int(input("Enter your number :-"))
    result = 12/num
except ZeroDivisionError:
    print("Division by zero")
else:
    print("Your result is :- ",result)
finally:
    print("All is well")
# Out:
# Enter your number :- 6
# Your result is :-  2.0
# All is well

# %% [markdown]
# - finally Block (Runs always)

# %%
try:
    num = int(input("Enter your number :-"))
    result = 12/num
except ZeroDivisionError:
    print("Division by zero")
else:
    print("Your result is :- ",result)
finally:
    print("All is well")
# Out:
# Enter your number :- 12
# Your result is :-  1.0
# All is well

# %% [markdown]
# - Multiple Exceptions Together

# %%
try:
    num = int(input("Enter your number :-"))
    result = 12/num
except (ZeroDivisionError,ValueError, TypeError):
    print("Invalid Entry....")
else:
    print("Your result is :- ",result)
finally:
    print("All is well")
# Out:
# Enter your number :- sassad
# Invalid Entry....
# All is well

# %% [markdown]
# ## Using Exception Object (as e)
#
# - Useful when you want exact error.

# %%
try:
    num = int(input("Enter your number :-"))
    result = 12/num
except ZeroDivisionError as ze:
    print(ze)
else:
    print("Your result is :- ",result)
finally:
    print("All is well")
# Out:
# Enter your number :- 0
# division by zero
# All is well

# %% [markdown]
# ## Raising Your Own Exception
#
# - You can create errors yourself.

# %%
age = int(input("Enter your Age :- "))
if age < 0:
    raise ValueError("Age cannot be negative .....")
# Out:
# Enter your Age :-  -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 3
#       1 age = int(input("Enter your Age :- "))
#       2 if age < 0:
# ----> 3     raise ValueError("Age cannot be negative .....")
#
# ValueError: Age cannot be negative .....

# %% [markdown]
# **Problem 1.** Given a list of string lst, returns sum of integers after parsing.
# If any element is non-convertible, raise ValurError with the index of first bad element.

# %%
def sum_ints(lst):
    total = 0
    for i,s in enumerate(lst):
        try:
            total += int(s)
        except ValueError as e:
            raise ValueError(f"Invalid integer at index {i}:{s}") from e
    return total

# %%
sum_ints([12,32,1232,442,56,'as'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 5, in sum_ints(lst)
#       4 try:
# ----> 5     total += int(s)
#       6 except ValueError as e:
#
# ValueError: invalid literal for int() with base 10: 'as'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sum_ints([12,32,1232,442,56,'as'])
#
# Cell In[28], line 7, in sum_ints(lst)
#       5         total += int(s)
#       6     except ValueError as e:
# ----> 7         raise ValueError(f"Invalid integer at index {i}:{s}") from e
#       8 return total
#
# ValueError: Invalid integer at index 5:as

# %% [markdown]
# ## Custom Exception

# %% [markdown]
# ## Example: ATM Machine
#
# - User tries to withdraw more money than available.

# %% [markdown]
# ## File Handling with Exception

# %%
try:
    f = open("Myfile")
    print(f.read())
except FileNotFoundError:
    print("File Does not exist........")
# Out:
# File Does not exist........

# %% [markdown]
# ## Most Common Exceptions
# | Exception           | Meaning                   |
# | ------------------- | ------------------------- |
# | `ZeroDivisionError` | divide by zero            |
# | `ValueError`        | wrong value in conversion |
# | `TypeError`         | wrong data type           |
# | `IndexError`        | invalid list index        |
# | `KeyError`          | invalid dictionary key    |
# | `FileNotFoundError` | file does not exist       |
# | `NameError`         | variable not defined      |
# | `AttributeError`    | attribute not found       |

# %% [markdown]
# ## Exception Handling Assignments.
# - Problem 1 — Safe conversion
# Write to_int(s) that converts s to int. If s can't be converted return None but do not suppress other exceptions (e.g., if s is None, a TypeError should propagate).
#
# - Problem 2 — Validate dict fields
# Write validate_user(user) where user must be dict with keys name (str) and age (int >= 0). Raise ValidationError listing missing/invalid fields.
#
# - Problem 3 — Handle KeyboardInterrupt gracefully
# Write loop that counts numbers and exits gracefully (print "Interrupted") when user presses Ctrl+C.
#
# - Problem 4. Invalid PIN Handling
# Write a program that asks the user for a 4-digit PIN.
# If the PIN is not 4 digits or contains non-digits → raise ValueError.
#
# - Problem 5. Insufficient Balance (Custom Exception)
# ATM withdrawal must raise custom InsufficientBalanceError if balance < amount.
#
# - Problem 6. Card Block After 3 Wrong PIN Attempts
# If user enters wrong PIN more than 3 times → raise CardBlockedError.
#
# - Problem 7. Cash Denomination Error
# ATM gives cash only in multiples of 100.
# If user enters any other amount → raise ValueError
#
# - Problem 8. ATM Card Expired Error
# If the expiry year < current year → raise CardExpiredError.
#
# - Problem 9. Maximum Withdrawal Limit
# Daily limit = 20,000
# If user enters amount > limit → raise custom LimitExceededError.
#
# - Problem 10. Detecting Fake Card
# If card number is not 16-digits → raise ValueError.
